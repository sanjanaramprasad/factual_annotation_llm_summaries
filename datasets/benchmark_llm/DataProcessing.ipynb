# %%
import json
import pandas as pd

# %%
def read_file(filepath):
    df_dict = {}
    with open(filepath, 'r') as fp:
        data = json.load(fp)
    for instance in data:
        for k , v in instance.items():
            if k not in df_dict:
                df_dict[k] = []
            df_dict[k].append(v)
    return pd.DataFrame(df_dict)

# %%
df = read_file('/home/ramprasad.sa/factual_annotation_llm_summaries/datasets/benchmark_llm/likert_evaluation_results.json')

# %%
df.to_csv('/home/ramprasad.sa/factual_annotation_llm_summaries/datasets/benchmark_llm/evaluation_results.csv')

# %%
df
# Out:
#                                                  article  \
# 0      (CNN)Two years ago, the storied Boston Maratho...
# 1      (CNN)Two years ago, the storied Boston Maratho...
# 2      (CNN)Two years ago, the storied Boston Maratho...
# 3      (CNN)Malala Yousafzai's stellar career has inc...
# 4      (CNN)Malala Yousafzai's stellar career has inc...
# ...                                                  ...
# 11095  David Jacques, from the University of Buckingh...
# 11096  David Jacques, from the University of Buckingh...
# 11097  The man, who has not been named, was dismissed...
# 11098  The man, who has not been named, was dismissed...
# 11099  The man, who has not been named, was dismissed...
#
#                        model  \
# 0      openai_curie (0 shot)
# 1      openai_curie (0 shot)
# 2      openai_curie (0 shot)
# 3      openai_curie (0 shot)
# 4      openai_curie (0 shot)
# ...                      ...
# 11095           openai_curie
# 11096           openai_curie
# ...
